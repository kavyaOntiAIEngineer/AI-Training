# %% [markdown]
# ## Q1. Load an image using PIL, then print its size and colour mode.

# %%
from PIL import Image

# Open the image
photo = Image.open("sample.jpg")

# Display information
print("Image Size :", photo.size)
print("Colour Mode :", photo.mode)
# Out:
# Image Size : (1155, 1733)
# Colour Mode : RGB

# %% [markdown]
# ## Q2. Convert an RGB image into a NumPy array and print its shape.

# %%
from PIL import Image
import numpy as np

# Read image
picture = Image.open("sample.jpg")

# Convert into NumPy array
image_array = np.array(picture)

print("Shape of Image :", image_array.shape)
# Out:
# Shape of Image : (1733, 1155, 3)

# %% [markdown]
# ## Q3. Normalize grayscale pixel values between 0 and 1.

# %%
from PIL import Image
import numpy as np

# Read image directly in grayscale
gray_img = Image.open("sample.jpg").convert("L")

pixels = np.array(gray_img)

# Normalize
normalized_pixels = pixels / 255.0

print(normalized_pixels)
# Out:
# [[0.39215686 0.38431373 0.38039216 ... 0.57254902 0.56862745 0.56862745]
#  [0.40392157 0.4        0.39607843 ... 0.58823529 0.58431373 0.58039216]
#  [0.42745098 0.42352941 0.41960784 ... 0.59607843 0.59215686 0.59215686]
#  ...
#  [0.34509804 0.34117647 0.34901961 ... 0.39607843 0.39607843 0.39607843]
#  [0.34117647 0.34117647 0.34901961 ... 0.37647059 0.37647059 0.37254902]
#  [0.3372549  0.34117647 0.35294118 ... 0.36862745 0.36862745 0.36862745]]

# %% [markdown]
# ## Q4. Reshape a grayscale image from (128,128) to CNN input format (1,128,128,1).

# %%
import numpy as np

# Dummy grayscale image
gray_image = np.random.randint(0, 256, (128, 128))

# Reshape for CNN
cnn_ready = gray_image.reshape(1, 128, 128, 1)

print("Original Shape :", gray_image.shape)
print("CNN Shape :", cnn_ready.shape)
# Out:
# Original Shape : (128, 128)
# CNN Shape : (1, 128, 128, 1)

# %% [markdown]
# ## Q5. Calculate total pixels in 512×512 grayscale and RGB image.

# %%
# Image dimensions
height = 512
width = 512

# Grayscale image
gray_pixels = height * width

# RGB image
rgb_values = height * width * 3

print("Grayscale Pixels :", gray_pixels)
print("RGB Values :", rgb_values)
# Out:
# Grayscale Pixels : 262144
# RGB Values : 786432

# %% [markdown]
# ## Q6. Create a 5×5 matrix of random pixel values.

# %%
import numpy as np

# Random pixel matrix
pixel_matrix = np.random.randint(
    low=0,
    high=256,
    size=(5,5),
    dtype=np.uint8
)

print(pixel_matrix)
# Out:
# [[190 224 251 234 144]
#  [106 224  62  84 243]
#  [213 223 209 233 198]
#  [182  96 128 230  93]
#  [173  59 158 105 202]]

# %% [markdown]
# ## Q7. Access pixel (50,50) and change it to pure white.

# %%
from PIL import Image
import numpy as np

# Load image
img = Image.open("sample.jpg")

img_array = np.array(img)

print("Original Pixel :", img_array[50, 50])

# Make pixel white
img_array[50, 50] = [255, 255, 255]

print("Updated Pixel :", img_array[50, 50])
# Out:
# Original Pixel : [49 53 16]
# Updated Pixel : [255 255 255]

# %% [markdown]
# ## Q8. Display original, grayscale and resized image using subplots.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load image
photo = Image.open("sample.jpg")

gray = photo.convert("L")
small = photo.resize((100,100))

fig, axes = plt.subplots(1,3,figsize=(12,4))

axes[0].imshow(photo)
axes[0].set_title("Original")
axes[0].axis("off")

axes[1].imshow(gray, cmap="gray")
axes[1].set_title("Grayscale")
axes[1].axis("off")

axes[2].imshow(small)
axes[2].set_title("100 x 100")
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q9. Plot histogram of grayscale image.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Read image
gray_photo = Image.open("sample.jpg").convert("L")

gray_array = np.array(gray_photo)

plt.figure(figsize=(7,4))

plt.hist(
    gray_array.ravel(),
    bins=256,
    color="gray"
)

plt.title("Pixel Intensity Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## Q10. Complete program to resize image to 224×224, convert to grayscale and save it.

# %%
from PIL import Image

# Input image
input_file = "sample.jpg"

# Read image
image = Image.open(input_file)

# Resize
image = image.resize((224,224))

# Convert to grayscale
image = image.convert("L")

# Save processed image
output_file = "processed_image.jpg"
image.save(output_file)

print("Image saved successfully as", output_file)
# Out:
# Image saved successfully as processed_image.jpg

# %% [markdown]
# ## Q11. Read an image, print its shape, and display it in RGB using Matplotlib.

# %%
import cv2
import matplotlib.pyplot as plt

# Load image
photo = cv2.imread("sample.jpg")

# Print image dimensions
print("Shape :", photo.shape)

# Convert BGR to RGB
rgb_photo = cv2.cvtColor(photo, cv2.COLOR_BGR2RGB)

# Display image
plt.imshow(rgb_photo)
plt.title("Original Image")
plt.axis("off")
plt.show()
# Out:
# Shape : (1733, 1155, 3)

# %% [markdown]
# ## Q12. Crop the centre 200×200 region.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg")
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

height, width = image.shape[:2]

center_x = width // 2
center_y = height // 2

cropped = rgb[
    center_y-100:center_y+100,
    center_x-100:center_x+100
]

plt.imshow(cropped)
plt.title("Center Crop")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q13. Rotate 90° clockwise and flip horizontally.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("sample.jpg")

rotated = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
flipped = cv2.flip(img, 1)

fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))
ax[0].set_title("Rotated")
ax[0].axis("off")

ax[1].imshow(cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB))
ax[1].set_title("Flipped")
ax[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q14. Convert image to HSV and display H, S and V channels.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg")

hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

h, s, v = cv2.split(hsv)

fig, axes = plt.subplots(1,3,figsize=(12,4))

axes[0].imshow(h, cmap="gray")
axes[0].set_title("Hue")
axes[0].axis("off")

axes[1].imshow(s, cmap="gray")
axes[1].set_title("Saturation")
axes[1].axis("off")

axes[2].imshow(v, cmap="gray")
axes[2].set_title("Value")
axes[2].axis("off")

plt.show()

# %% [markdown]
# ## Q15. Draw a rectangle at the centre and add a label.

# %%
import cv2
import matplotlib.pyplot as plt

picture = cv2.imread("sample.jpg")

h, w = picture.shape[:2]

start = (w//2 - 100, h//2 - 100)
end = (w//2 + 100, h//2 + 100)

cv2.rectangle(
    picture,
    start,
    end,
    (0,255,0),
    3
)

cv2.putText(
    picture,
    "Center",
    (start[0], start[1]-15),
    cv2.FONT_HERSHEY_SIMPLEX,
    0.8,
    (255,0,0),
    2
)

plt.imshow(cv2.cvtColor(picture, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q16. Apply Gaussian, Median and Bilateral filters.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg")

gaussian = cv2.GaussianBlur(image, (7,7), 0)

median = cv2.medianBlur(image, 7)

bilateral = cv2.bilateralFilter(image, 9, 75, 75)

fig, ax = plt.subplots(1,3,figsize=(14,5))

ax[0].imshow(cv2.cvtColor(gaussian, cv2.COLOR_BGR2RGB))
ax[0].set_title("Gaussian")

ax[1].imshow(cv2.cvtColor(median, cv2.COLOR_BGR2RGB))
ax[1].set_title("Median")

ax[2].imshow(cv2.cvtColor(bilateral, cv2.COLOR_BGR2RGB))
ax[2].set_title("Bilateral")

for i in ax:
    i.axis("off")

plt.show()

# %% [markdown]
# ## Q17. Apply Binary and Binary Inverse thresholding.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg", 0)

_, binary = cv2.threshold(
    image,
    120,
    255,
    cv2.THRESH_BINARY
)

_, inverse = cv2.threshold(
    image,
    120,
    255,
    cv2.THRESH_BINARY_INV
)

fig, ax = plt.subplots(1,2,figsize=(10,4))

ax[0].imshow(binary, cmap="gray")
ax[0].set_title("Binary")

ax[1].imshow(inverse, cmap="gray")
ax[1].set_title("Binary Inverse")

for x in ax:
    x.axis("off")

plt.show()

# %% [markdown]
# ## Q18. Detect edges using Canny.

# %%
import cv2
import matplotlib.pyplot as plt

photo = cv2.imread("sample.jpg", 0)

edges = cv2.Canny(
    photo,
    100,
    200
)

plt.imshow(edges, cmap="gray")
plt.title("Detected Edges")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q19. Find and draw contours.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, thresh = cv2.threshold(
    gray,
    120,
    255,
    cv2.THRESH_BINARY
)

contours, hierarchy = cv2.findContours(
    thresh,
    cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE
)

result = image.copy()

cv2.drawContours(
    result,
    contours,
    -1,
    (0,255,0),
    2
)

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.title("Contours")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q20. Complete OpenCV Mini Pipeline

# %%
import cv2
import matplotlib.pyplot as plt

# Step 1 : Read image
image = cv2.imread("sample.jpg")

# Step 2 : Resize
resized = cv2.resize(image, (300,300))

# Step 3 : Convert to grayscale
gray = cv2.cvtColor(
    resized,
    cv2.COLOR_BGR2GRAY
)

# Step 4 : Blur image
blurred = cv2.GaussianBlur(
    gray,
    (5,5),
    0
)

# Step 5 : Detect edges
edges = cv2.Canny(
    blurred,
    100,
    200
)

# Display every stage
fig, ax = plt.subplots(1,4,figsize=(16,5))

ax[0].imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
ax[0].set_title("Resized")

ax[1].imshow(gray, cmap="gray")
ax[1].set_title("Gray")

ax[2].imshow(blurred, cmap="gray")
ax[2].set_title("Blur")

ax[3].imshow(edges, cmap="gray")
ax[3].set_title("Edges")

for item in ax:
    item.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q21. Build a CNN with two Conv2D + MaxPooling blocks, Flatten, and two Dense layers.

# %%
# Import TensorFlow Keras libraries
from tensorflow.keras.models import Sequential, load_model

# Import CNN layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout

# Import optimizer
from tensorflow.keras.optimizers import Adam

# Import callbacks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Import NumPy
import numpy as np

# Import Matplotlib
import matplotlib.pyplot as plt# Create a Sequential CNN model
model = Sequential()

# Add first Convolution layer
# 32 filters of size 3x3 with ReLU activation
# Input image size is 224x224 with 3 colour channels
model.add(Conv2D(32, (3,3), activation="relu", input_shape=(224,224,3)))

# Reduce image size using MaxPooling
model.add(MaxPooling2D((2,2)))

# Add second Convolution layer with 64 filters
model.add(Conv2D(64, (3,3), activation="relu"))

# Reduce feature map size again
model.add(MaxPooling2D((2,2)))

# Convert 2D feature maps into 1D vector
model.add(Flatten())

# Add Fully Connected (Dense) layer
model.add(Dense(128, activation="relu"))

# Output layer with 10 classes using Softmax
model.add(Dense(10, activation="softmax"))

# Display model architecture
model.summary()
# Out:
# c:\Users\dell\anaconda3\Anaconda\envs\myenv6\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## Q22. Compile using Adam optimizer (Learning Rate = 0.001)

# %%
# Create Adam optimizer with learning rate 0.001
optimizer = Adam(learning_rate=0.001)

# Compile the CNN model
model.compile(

    # Optimizer used for training
    optimizer=optimizer,

    # Loss function for multi-class classification
    loss="categorical_crossentropy",

    # Measure model accuracy
    metrics=["accuracy"]

)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Q23. Calculate output shape

# %%
# Input Image = 10 × 10

# Filter Size = 3 × 3

# Stride = 1

# Padding = 0

# After Conv2D
# Formula = (Input - Filter) / Stride + 1
# (10 - 3) / 1 + 1 = 8

print("After Conv2D = 8 x 8")

# After MaxPooling (2 × 2)

# 8 / 2 = 4

print("After MaxPooling = 4 x 4")
# Out:
# After Conv2D = 8 x 8
# After MaxPooling = 4 x 4

# %% [markdown]
# ## Q24. Add Batch Normalization and Dropout.

# %%
# Create a new CNN model
model = Sequential()

# Add Convolution layer
model.add(Conv2D(32,(3,3),activation="relu",input_shape=(224,224,3)))

# Normalize feature maps
model.add(BatchNormalization())

# Reduce image size
model.add(MaxPooling2D((2,2)))

# Convert feature maps into vector
model.add(Flatten())

# Fully Connected Layer
model.add(Dense(128,activation="relu"))

# Randomly drop 50% neurons
# Helps reduce overfitting
model.add(Dropout(0.5))

# Output layer
model.add(Dense(10,activation="softmax"))

# %% [markdown]
# ## Q25. Train for 15 epochs with EarlyStopping.

# %%
# Import NumPy
import numpy as np

# Create dummy training images
X_train = np.random.rand(100, 224, 224, 3)

# Create dummy training labels (10 classes)
y_train = np.eye(10)[np.random.randint(0, 10, 100)]

# Create dummy testing images
X_test = np.random.rand(20, 224, 224, 3)

# Create dummy testing labels (10 classes)
y_test = np.eye(10)[np.random.randint(0, 10, 20)]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Create EarlyStopping callback
early_stop = EarlyStopping(

    # Monitor validation loss
    monitor="val_loss",

    # Stop training after 3 epochs without improvement
    patience=3

)

# Train the model
history = model.fit(

    # Training images
    X_train,

    # Training labels
    y_train,

    # Number of training cycles
    epochs=15,

    # Images processed at one time
    batch_size=32,

    # Validation dataset
    validation_data=(X_test, y_test),

    # Apply EarlyStopping
    callbacks=[early_stop]

)
# Out:
# Epoch 1/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step - accuracy: 0.1100 - loss: 254.9914 - val_accuracy: 0.1000 - val_loss: 64.9079
# Epoch 2/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 644ms/step - accuracy: 0.1400 - loss: 179.2133 - val_accuracy: 0.1000 - val_loss: 30.6266
# Epoch 3/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 990ms/step - accuracy: 0.1600 - loss: 96.4270 - val_accuracy: 0.1500 - val_loss: 8.7973
# Epoch 4/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 802ms/step - accuracy: 0.1900 - loss: 11.0706 - val_accuracy: 0.1500 - val_loss: 2.3022
# Epoch 5/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 843ms/step - accuracy: 0.1500 - loss: 2.7695 - val_accuracy: 0.1500 - val_loss: 2.3020
# Epoch 6/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 578ms/step - accuracy: 0.1300 - loss: 3.4337 - val_accuracy: 0.1500 - val_loss: 2.3018
# Epoch 7/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 602ms/step - accuracy: 0.1200 - loss: 2.5661 - val_accuracy: 0.1500 - val_loss: 2.3015
# Epoch 8/15
# ...
