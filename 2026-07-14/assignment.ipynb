# %% [markdown]
# ## Q1

# %%
sentence = "I love Artificial Intelligence"
print(type(sentence))
# Out:
# <class 'str'>

# %% [markdown]
# ## Q2

# %%
sentence = "I love NLP"
print(len(sentence))
# Out:
# 10

# %% [markdown]
# ## Q3

# %%
sentence = "I love Natural Language Processing"
words = sentence.split()
print(words)
print(len(words))
# Out:
# ['I', 'love', 'Natural', 'Language', 'Processing']
# 5

# %% [markdown]
# ## Q4

# %%
message = "You have won a free prize"

if "free" in message:
    print("Word found")
else:
    print("Word not found")
# Out:
# Word found

# %% [markdown]
# ## Q5

# %%
message = "Congratulations! You won a prize."

if "Congratulations" in message:
    print("Possible Spam")
else:
    print("Not Spam")
# Out:
# Possible Spam

# %% [markdown]
# ## Q6

# %%
import pandas as pd

data = {
    "Review": [
        "Amazing Phone",
        "Worst Battery",
        "Excellent Camera",
        "Bad Display"
    ],
    "Sentiment": [
        "Positive",
        "Negative",
        "Positive",
        "Negative"
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#              Review Sentiment
# 0     Amazing Phone  Positive
# 1     Worst Battery  Negative
# 2  Excellent Camera  Positive
# 3       Bad Display  Negative

# %% [markdown]
# ## Q7

# %%
print(df.shape)
print(df.info())
# Out:
# (4, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Review     4 non-null      str
#  1   Sentiment  4 non-null      str
# dtypes: str(2)
# memory usage: 196.0 bytes
# None

# %% [markdown]
# ## Q8

# %%
print(df.head())
print(df.tail())
# Out:
#              Review Sentiment
# 0     Amazing Phone  Positive
# 1     Worst Battery  Negative
# 2  Excellent Camera  Positive
# 3       Bad Display  Negative
#              Review Sentiment
# 0     Amazing Phone  Positive
# 1     Worst Battery  Negative
# 2  Excellent Camera  Positive
# 3       Bad Display  Negative

# %% [markdown]
# ## Q9

# %%
print(df["Sentiment"].value_counts())
# Out:
# Sentiment
# Positive    2
# Negative    2
# Name: count, dtype: int64

# %% [markdown]
# ## Q10

# %%
df["Review"] = df["Review"].str.lower()
print(df)
# Out:
#              Review Sentiment
# 0     amazing phone  Positive
# 1     worst battery  Negative
# 2  excellent camera  Positive
# 3       bad display  Negative

# %% [markdown]
# ## Q11

# %%
df["Length"] = df["Review"].apply(len)
print(df)
# Out:
#              Review Sentiment  Length
# 0     amazing phone  Positive      13
# 1     worst battery  Negative      13
# 2  excellent camera  Positive      16
# 3       bad display  Negative      11

# %% [markdown]
# ## Q12

# %%
for review in df["Review"]:
    print(review)
# Out:
# amazing phone
# worst battery
# excellent camera
# bad display

# %% [markdown]
# ## Q13

# %%
print(df["Review"].str.contains("phone", case=False))
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: Review, dtype: bool

# %% [markdown]
# ## Q14

# %%
positive_reviews = df[df["Sentiment"] == "Positive"]
print(positive_reviews)
# Out:
#              Review Sentiment  Length
# 0     amazing phone  Positive      13
# 2  excellent camera  Positive      16

# %% [markdown]
# ## Q15

# %%
df["Characters"] = df["Review"].str.len()
print(df)
# Out:
#              Review Sentiment  Length  Characters
# 0     amazing phone  Positive      13          13
# 1     worst battery  Negative      13          13
# 2  excellent camera  Positive      16          16
# 3       bad display  Negative      11          11

# %% [markdown]
# ## Q16

# %%
df["Words"] = df["Review"].apply(lambda x: len(x.split()))
print(df)
# Out:
#              Review Sentiment  Length  Characters  Words
# 0     amazing phone  Positive      13          13      2
# 1     worst battery  Negative      13          13      2
# 2  excellent camera  Positive      16          16      2
# 3       bad display  Negative      11          11      2

# %% [markdown]
# ## Q17

# %%
import pandas as pd

movies = {
    "Review": [
        "Amazing movie",
        "Worst film ever",
        "Loved every scene",
        "Very boring movie",
        "Excellent acting",
        "Waste of time"
    ],
    "Sentiment": [
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Positive",
        "Negative"
    ]
}

df = pd.DataFrame(movies)

negative = df[df["Sentiment"] == "Negative"]
print(negative)
# Out:
#               Review Sentiment
# 1    Worst film ever  Negative
# 3  Very boring movie  Negative
# 5      Waste of time  Negative

# %% [markdown]
# ## Q18

# %%
df["Length"] = df["Review"].str.len()

longest = df[df["Length"] == df["Length"].max()]

print(longest)
# Out:
#               Review Sentiment  Length
# 2  Loved every scene  Positive      17
# 3  Very boring movie  Negative      17

# %% [markdown]
# ## Q19

# %%
print(df["Sentiment"].value_counts())
# Out:
# Sentiment
# Positive    3
# Negative    3
# Name: count, dtype: int64

# %% [markdown]
# ## Q20

# %%
import pandas as pd

feedback = {
    "Feedback": [
        "Excellent teaching",
        "Need more examples",
        "Very helpful class",
        "Too fast",
        "Good explanation",
        "Confusing topics",
        "Loved the practicals",
        "Assignments are difficult",
        "Very informative",
        "Need more practice"
    ],
    "Sentiment": [
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Positive",
        "Negative"
    ]
}

df = pd.DataFrame(feedback)

print(df.head())
print(df.tail())
# Out:
#              Feedback Sentiment
# 0  Excellent teaching  Positive
# 1  Need more examples  Negative
# 2  Very helpful class  Positive
# 3            Too fast  Negative
# 4    Good explanation  Positive
#                     Feedback Sentiment
# 5           Confusing topics  Negative
# 6       Loved the practicals  Positive
# 7  Assignments are difficult  Negative
# 8           Very informative  Positive
# 9         Need more practice  Negative
